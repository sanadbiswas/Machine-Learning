# %% [markdown]
# Regression Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
plt.xlabel("area(sq ft)", fontsize=20)
plt.ylabel("price($US)", fontsize=20)
plt.scatter(df.area,df.price, color="red", marker="*")

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
# %matplotlib inline 
plt.xlabel("area(sq ft)", fontsize=20)
plt.ylabel("price($US)", fontsize=20)
plt.scatter(df.area,df.price, color="red", marker="*")
plt.plot(df.area,reg.predict(df[["area"]]),color="blue")

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
d=pd.read_csv("areas.csv")
d.head(5)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
reg.predict(d)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
p=reg.predict(d)

# %%
d["predicted prices"]=p
d.head(5)
# Out:
#    area  predicted prices
# 0  1000     316404.109589
# 1  1500     384297.945205
# 2  2300     492928.082192
# 3  3540     661304.794521
# 4  4120     740061.643836

# %%
d.to_csv("prediction.csv") # create a csv file in the name "prediction.csv" with index column
#d.to_csv("prediction.csv", index=False) # create a csv file without index in the name "prediction.csv"

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["year"]],df["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %% [raw]
# Source Code:codebasics
